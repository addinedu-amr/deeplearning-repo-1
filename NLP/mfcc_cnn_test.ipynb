# %% [markdown]
# # Import

# %%
import os
import librosa 
import sklearn
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import librosa.display
import tensorflow as tf

from tqdm import tqdm
from scipy.io import wavfile as wav
# Out:
# 2023-01-19 11:30:09.362498: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-01-19 11:30:09.597394: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-01-19 11:30:10.699577: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/usr/local/cuda-11.3/lib64
# 2023-01-19 11:30:10.699677: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/usr/local/cuda-11.3/lib64
# 2023-01-19 11:30:10.699682: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
  try:
    # Currently, memory growth needs to be the same across GPUs
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
    logical_gpus = tf.config.experimental.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
  except RuntimeError as e:
    # Memory growth must be set before GPUs have been initialized
    print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs
# 2023-01-19 11:30:13.235158: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-19 11:30:13.272631: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-19 11:30:13.273140: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-19 11:30:13.274823: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-01-19 11:30:13.275861: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-19 11:30:13.276265: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-19 11:30:13.276629: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-19 11:30:13.969253: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-19 11:30:13.970137: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-19 11:30:13.970498: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-19 11:30:13.970808: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 4041 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6

# %% [markdown]
# ## 예시

# %%
sound_bad = '../record/안좋아요_1.wav'

# %%
example_list = [sound_bad]#, filename_laugh, filename_noise, filename_silence, filename_fall]
librosa_sample_rate  = 0

# %%
def draw_sound(filename):
    plt.figure(figsize = (12, 4))
    data, librosa_sample_rate  = librosa.load(filename)
    plt.title('sound_bad_1.wav')
    librosa.display.waveshow(data, sr = librosa_sample_rate)

# %%
for i in  example_list:
    draw_sound(i)

# %%
# melspectrogram
y, sr = librosa.load(sound_bad)
yt, _ = librosa.effects.trim(y)
y = yt
plt.title('Mel spectrum')
mel_spect = librosa.feature.melspectrogram(y=y, sr=sr, n_fft=1024, hop_length=100)
mel_spect = librosa.power_to_db(mel_spect, ref=np.max)
librosa.display.specshow(mel_spect, y_axis='mel', fmax=20000, x_axis='time')

# %%
# mfcc

filename = '../record/안좋아요_1.wav' 

librosa_audio, librosa_sample_rate = librosa.load(filename) 
# scipy_sample_rate, scipy_audio = wav.read(filename) 
print(librosa_audio.shape)
# print('Original sample rate:', scipy_sample_rate) 
print('Librosa sample rate:', librosa_sample_rate) 

mfccs = librosa.feature.mfcc(y = librosa_audio, sr = librosa_sample_rate, n_mfcc = n_mfcc)
print(mfccs.shape)
# Out:
# (32256,)
# Librosa sample rate: 22050
# (40, 64)

# %%
plt.title('MFCC')
librosa.display.specshow(mfccs, sr=librosa_sample_rate)
plt.xlabel('Time')
plt.ylabel('MFCC coeff')
# Out:
# Text(0, 0.5, 'MFCC coeff')

# %%
train_path = os.listdir('../record/')
train_path
# Out:
# ['안좋아요_8.wav',
#  '안좋아요_7.wav',
#  '아_8.wav',
#  '좋아요_10.wav',
#  '아_1.wav',
#  '안좋아요_1.wav',
#  '좋아요_8.wav',
#  '좋아요_3.wav',
#  '안좋아요_14.wav',
#  '좋아요_13.wav',
#  '좋아요_15.wav',
#  '좋아요_14.wav',
#  '아_13.wav',
#  '아_9.wav',
#  '안좋아요_9.wav',
#  '아_7.wav',
#  '아_4.wav',
#  '좋아요_7.wav',
#  '안좋아요_11.wav',
#  '안좋아요_2.wav',
#  '안좋아요_4.wav',
#  '좋아요_12.wav',
#  '좋아요_5.wav',
#  '아_15.wav',
#  '좋아요_1.wav',
#  '아_14.wav',
#  '안좋아요_12.wav',
#  '아_5.wav',
#  '좋아요_4.wav',
#  '안좋아요_3.wav',
#  '안좋아요_6.wav',
#  '안좋아요_15.wav',
#  '안좋아요_10.wav',
#  '아_11.wav',
#  '좋아요_11.wav',
#  '아_2.wav',
#  '안좋아요_13.wav',
#  '아_10.wav',
#  '좋아요_2.wav',
#  '아_12.wav',
#  '좋아요_9.wav',
#  '안좋아요_5.wav',
#  '아_6.wav',
#  '좋아요_6.wav',
#  '아_3.wav']

# %% [markdown]
# # 데이터

# %%
# wav_dict = {
#             '아' : 0,
#             '좋아요' : 1,
#             '안좋아요' : 2,
#             '힘들어' : 3,
#             '피곤해' : 4,
#             '별로야' : 5,
#             '하기싫다' : 6,
#             '좋아' : 7
#             }

# %%
wav_dict = {
            '아니요' : 0,
            '네' : 1
            }

# %%
# # Change audio names 'yes_1.wav' --> '1.yes_1.wav'
# import os
# for wav in os.listdir(f'../record_yes_no/'):
#     if '아니요' in wav:
#         os.rename(f'../record_yes_no/{wav}', '../record_yes_no/1.'+f'{wav}')

# %%
wav_files = []

for file in os.listdir(f'../record_yes_no/'):
    wav_files.append(f'../record_yes_no/{file}')
    
wav_df = pd.DataFrame({'path': wav_files})
wav_df['label'] = wav_df['path'].apply(lambda x: x.split('/')[-1])
wav_df['label'] = wav_df['label'].apply(lambda x: x.split('.')[1])
wav_df['label'] = wav_df['label'].apply(lambda x: x.split('_')[0])

wav_df
# Out:
#                                  path label
# 0       ../record_yes_no/1.아니요_19.wav   아니요
# 1         ../record_yes_no/1.네_33.wav     네
# 2    ../record_yes_no/1.아니요_준석형_3.wav   아니요
# 3       ../record_yes_no/1.아니요_32.wav   아니요
# 4       ../record_yes_no/1.아니요_16.wav   아니요
# ..                                ...   ...
# 143       ../record_yes_no/1.네_38.wav     네
# 144       ../record_yes_no/1.네_81.wav     네
# 145       ../record_yes_no/1.네_67.wav     네
# 146        ../record_yes_no/1.네_6.wav     네
# 147       ../record_yes_no/1.네_31.wav     네
#
# [148 rows x 2 columns]

# %%
wav_df['label']
# Out:
# 0      아니요
# 1        네
# 2      아니요
# 3      아니요
# 4      아니요
#       ...
# 143      네
# 144      네
# 145      네
# 146      네
# 147      네
# Name: label, Length: 148, dtype: object

# %% [markdown]
# ## 라벨로 변환

# %%
class_label = []

for label in wav_df['label']:
    if label in wav_dict:
        class_label.append(wav_dict[label])
        
wav_df['class_label'] = class_label
wav_df
# Out:
#                                  path label  class_label
# 0       ../record_yes_no/1.아니요_19.wav   아니요            0
# 1         ../record_yes_no/1.네_33.wav     네            1
# 2    ../record_yes_no/1.아니요_준석형_3.wav   아니요            0
# 3       ../record_yes_no/1.아니요_32.wav   아니요            0
# 4       ../record_yes_no/1.아니요_16.wav   아니요            0
# ..                                ...   ...          ...
# 143       ../record_yes_no/1.네_38.wav     네            1
# 144       ../record_yes_no/1.네_81.wav     네            1
# 145       ../record_yes_no/1.네_67.wav     네            1
# 146        ../record_yes_no/1.네_6.wav     네            1
# 147       ../record_yes_no/1.네_31.wav     네            1
#
# [148 rows x 3 columns]

# %%
from sklearn.model_selection import train_test_split

train_data, test_data = train_test_split(wav_df,
                                        test_size=0.1,
                                        stratify=wav_df['class_label'],
                                        random_state=7)

# %%
train_data, val_data = train_test_split(train_data,
                                        test_size=0.2,
                                        stratify=train_data['class_label'],
                                        random_state=7)

# %%
len(train_data), len(val_data), len(test_data)
# Out:
# (106, 27, 15)

# %%
X_train = train_data['path']
y_train = train_data['class_label']

# %%
X_val = val_data['path']
y_val = val_data['class_label']

# %%
# Search the max_len of mfccs
n_mfcc = 40  # Initialize n_mfcc
shapes= []

for i in range(len(wav_df)):
    librosa_audio, librosa_sample_rate = librosa.load(wav_df.iloc[i, 0]) 
    mfccs = librosa.feature.mfcc(y = librosa_audio, sr = librosa_sample_rate, n_mfcc = n_mfcc)
    shapes.append(mfccs.shape[1])

print('max_len :', max(shapes))
print(librosa_sample_rate)
# Out:
# max_len : 248
# 22050

# %%
max_pad_len = max(shapes)

def extract_feature(file_name):
    print('file name :', file_name)
    try:
        audio, sample_rate = librosa.load(file_name, res_type='kaiser_fast')
        mfccs = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=n_mfcc)
        pad_width = max_pad_len - mfccs.shape[1]
        mfccs = np.pad(mfccs, pad_width=((0,0), (0, pad_width)), mode='constant')
        print(mfccs.shape)
        
    except Exception as e:
        print("Error encountered while parsing file: ", file_name)
        print(e);
        return None
    
#     return padded_mfccs
    return mfccs

# %%
features_train = []

for i, wav in enumerate(X_train):
    mfccs = extract_feature(wav)
    features_train.append([mfccs, y_train.values[i]])#, y_train[i]])

features_df = pd.DataFrame(features_train, columns=['feature', 'class_label'])
# Out:
# file name : ../record_yes_no/1.아니요_4.wav
# (40, 248)
# file name : ../record_yes_no/1.네_39.wav
# (40, 248)
# file name : ../record_yes_no/1.네_14.wav
# (40, 248)
# file name : ../record_yes_no/1.네_97.wav
# (40, 248)
# file name : ../record_yes_no/1.네_55.wav
# (40, 248)
# file name : ../record_yes_no/1.아니요_29.wav
# (40, 248)
# file name : ../record_yes_no/1.아니요_20.wav
# (40, 248)
# file name : ../record_yes_no/1.아니요_준석형_3.wav
# (40, 248)
# file name : ../record_yes_no/1.아니요_13.wav
# (40, 248)
# file name : ../record_yes_no/1.네_89.wav
# (40, 248)
# file name : ../record_yes_no/1.네_47.wav
# (40, 248)
# file name : ../record_yes_no/1.네_28.wav
# (40, 248)
# file name : ../record_yes_no/1.네_71.wav
# (40, 248)
# file name : ../record_yes_no/1.네_87.wav
# (40, 248)
# file name : ../record_yes_no/1.아니요_31.wav
# (40, 248)
# file name : ../record_yes_no/1.네_64.wav
# (40, 248)
# file name : ../record_yes_no/1.아니요_19.wav
# (40, 248)
# file name : ../record_yes_no/1.아니요_10.wav
# (40, 248)
# file name : ../record_yes_no/1.네_8.wav
# (40, 248)
# file name : ../record_yes_no/1.네_100.wav
# (40, 248)
# file name : ../record_yes_no/1.아니요_35.wav
# (40, 248)
# file name : ../record_yes_no/1.네_61.wav
# (40, 248)
# file name : ../record_yes_no/1.아니요_32.wav
# (40, 248)
# file name : ../record_yes_no/1.네_56.wav
# (40, 248)
# file name : ../record_yes_no/1.네_24.wav
# (40, 248)
# file name : ../record_yes_no/1.네_76.wav
# (40, 248)
# file name : ../record_yes_no/1.네_57.wav
# (40, 248)
# file name : ../record_yes_no/1.네_42.wav
# (40, 248)
# file name : ../record_yes_no/1.네_46.wav
# (40, 248)
# file name : ../record_yes_no/1.네_4.wav
# (40, 248)
# file name : ../record_yes_no/1.네_18.wav
# (40, 248)
# file name : ../record_yes_no/1.네_44.wav
# (40, 248)
# file name : ../record_yes_no/1.네_40.wav
# (40, 248)
# file name : ../record_yes_no/1.아니요_26.wav
# (40, 248)
# file name : ../record_yes_no/1.네_33.wav
# (40, 248)
# file name : ../record_yes_no/1.네_94.wav
# (40, 248)
# file name : ../record_yes_no/1.네_19.wav
# (40, 248)
# file name : ../record_yes_no/1.아니요_6.wav
# (40, 248)
# file name : ../record_yes_no/1.네_1.wav
# (40, 248)
# file name : ../record_yes_no/1.아니요_17.wav
# (40, 248)
# file name : ../record_yes_no/1.아니요_24.wav
# (40, 248)
# file name : ../record_yes_no/1.네_74.wav
# (40, 248)
# file name : ../record_yes_no/1.아니요_37.wav
# (40, 248)
# file name : ../record_yes_no/1.네_81.wav
# (40, 248)
# file name : ../record_yes_no/1.아니요_14.wav
# (40, 248)
# file name : ../record_yes_no/1.네_12.wav
# (40, 248)
# file name : ../record_yes_no/1.네_32.wav
# (40, 248)
# file name : ../record_yes_no/1.네_79.wav
# (40, 248)
# file name : ../record_yes_no/1.아니요_40.wav
# (40, 248)
# file name : ../record_yes_no/1.네_91.wav
# (40, 248)
# file name : ../record_yes_no/1.네_98.wav
# (40, 248)
# file name : ../record_yes_no/1.네_53.wav
# (40, 248)
# file name : ../record_yes_no/1.네_37.wav
# (40, 248)
# file name : ../record_yes_no/1.아니요_22.wav
# (40, 248)
# file name : ../record_yes_no/1.네_73.wav
# (40, 248)
# file name : ../record_yes_no/1.네_86.wav
# (40, 248)
# file name : ../record_yes_no/1.아니요_7.wav
# (40, 248)
# file name : ../record_yes_no/1.네_49.wav
# (40, 248)
# file name : ../record_yes_no/1.아니요_준석형_2.wav
# (40, 248)
# file name : ../record_yes_no/1.아니요_동준님_1.wav
# (40, 248)
# file name : ../record_yes_no/1.네_92.wav
# (40, 248)
# file name : ../record_yes_no/1.네_77.wav
# (40, 248)
# file name : ../record_yes_no/1.네_72.wav
# (40, 248)
# file name : ../record_yes_no/1.아니요_12.wav
# (40, 248)
# file name : ../record_yes_no/1.아니요_5.wav
# (40, 248)
# file name : ../record_yes_no/1.네_41.wav
# (40, 248)
# file name : ../record_yes_no/1.네_31.wav
# (40, 248)
# file name : ../record_yes_no/1.아니요_36.wav
# (40, 248)
# file name : ../record_yes_no/1.네_69.wav
# (40, 248)
# file name : ../record_yes_no/1.네_58.wav
# (40, 248)
# file name : ../record_yes_no/1.아니요_23.wav
# (40, 248)
# file name : ../record_yes_no/1.아니요_18.wav
# (40, 248)
# file name : ../record_yes_no/1.네_6.wav
# (40, 248)
# file name : ../record_yes_no/1.아니요_동준님_2.wav
# (40, 248)
# file name : ../record_yes_no/1.아니요_2.wav
# (40, 248)
# file name : ../record_yes_no/1.아니요_11.wav
# (40, 248)
# file name : ../record_yes_no/1.네_99.wav
# (40, 248)
# file name : ../record_yes_no/1.네_38.wav
# (40, 248)
# file name : ../record_yes_no/1.네_20.wav
# (40, 248)
# file name : ../record_yes_no/1.아니요_경환님_1.wav
# (40, 248)
# file name : ../record_yes_no/1.네_2.wav
# (40, 248)
# file name : ../record_yes_no/1.네_90.wav
# (40, 248)
# file name : ../record_yes_no/1.네_26.wav
# (40, 248)
# file name : ../record_yes_no/1.네_62.wav
# (40, 248)
# file name : ../record_yes_no/1.네_36.wav
# (40, 248)
# file name : ../record_yes_no/1.아니요_33.wav
# (40, 248)
# file name : ../record_yes_no/1.네_10.wav
# (40, 248)
# file name : ../record_yes_no/1.네_27.wav
# (40, 248)
# file name : ../record_yes_no/1.네_48.wav
# (40, 248)
# file name : ../record_yes_no/1.아니요_9.wav
# (40, 248)
# file name : ../record_yes_no/1.네_35.wav
# (40, 248)
# file name : ../record_yes_no/1.네_95.wav
# (40, 248)
# file name : ../record_yes_no/1.아니요_34.wav
# (40, 248)
# file name : ../record_yes_no/1.네_63.wav
# (40, 248)
# file name : ../record_yes_no/1.네_34.wav
# (40, 248)
# file name : ../record_yes_no/1.네_13.wav
# (40, 248)
# file name : ../record_yes_no/1.아니요_3.wav
# (40, 248)
# file name : ../record_yes_no/1.아니요_8.wav
# (40, 248)
# file name : ../record_yes_no/1.네_52.wav
# (40, 248)
# file name : ../record_yes_no/1.네_78.wav
# (40, 248)
# file name : ../record_yes_no/1.네_85.wav
# (40, 248)
# file name : ../record_yes_no/1.네_84.wav
# (40, 248)
# file name : ../record_yes_no/1.네_30.wav
# (40, 248)
# file name : ../record_yes_no/1.네_16.wav
# (40, 248)
# file name : ../record_yes_no/1.네_21.wav
# (40, 248)
# file name : ../record_yes_no/1.네_43.wav
# (40, 248)

# %%
features_df
# Out:
#                                                feature  class_label
# 0    [[-633.709, -633.709, -633.709, -552.78577, -4...            0
# 1    [[-735.5697, -735.5697, -553.3372, -455.7941, ...            1
# 2    [[-628.5372, -628.5372, -627.88934, -520.47705...            1
# 3    [[-559.63336, -444.73737, -191.94516, -161.747...            1
# 4    [[-590.7834, -590.7834, -530.31683, -493.1276,...            1
# ..                                                 ...          ...
# 101  [[-592.68933, -592.68933, -580.494, -536.1528,...            1
# 102  [[-691.9137, -691.9137, -615.902, -552.9339, -...            1
# 103  [[-585.1644, -585.1644, -578.4522, -474.28503,...            1
# 104  [[-557.2895, -531.5133, -526.0311, -510.5877, ...            1
# 105  [[-590.2483, -548.2608, -534.4405, -517.72437,...            1
#
# [106 rows x 2 columns]

# %%
features_val = []

for i, wav in enumerate(X_val):
    mfccs = extract_feature(wav)
    features_val.append([mfccs, y_val.values[i]])#, y_val[i]])

features_val_df = pd.DataFrame(features_val, columns=['feature', 'class_label'])
# Out:
# file name : ../record_yes_no/1.네_88.wav
# (40, 248)
# file name : ../record_yes_no/1.아니요_준석형_1.wav
# (40, 248)
# file name : ../record_yes_no/1.아니요_25.wav
# (40, 248)
# file name : ../record_yes_no/1.네_3.wav
# (40, 248)
# file name : ../record_yes_no/1.아니요_21.wav
# (40, 248)
# file name : ../record_yes_no/1.네_96.wav
# (40, 248)
# file name : ../record_yes_no/1.네_15.wav
# (40, 248)
# file name : ../record_yes_no/1.네_54.wav
# (40, 248)
# file name : ../record_yes_no/1.네_25.wav
# (40, 248)
# file name : ../record_yes_no/1.네_65.wav
# (40, 248)
# file name : ../record_yes_no/1.네_80.wav
# (40, 248)
# file name : ../record_yes_no/1.네_7.wav
# (40, 248)
# file name : ../record_yes_no/1.네_22.wav
# (40, 248)
# file name : ../record_yes_no/1.아니요_41.wav
# (40, 248)
# file name : ../record_yes_no/1.아니요_27.wav
# (40, 248)
# file name : ../record_yes_no/1.네_60.wav
# (40, 248)
# file name : ../record_yes_no/1.네_5.wav
# (40, 248)
# file name : ../record_yes_no/1.아니요_38.wav
# (40, 248)
# file name : ../record_yes_no/1.아니요_15.wav
# (40, 248)
# file name : ../record_yes_no/1.네_68.wav
# (40, 248)
# file name : ../record_yes_no/1.네_93.wav
# (40, 248)
# file name : ../record_yes_no/1.아니요_경환님_2.wav
# (40, 248)
# file name : ../record_yes_no/1.아니요_경환님_3.wav
# (40, 248)
# file name : ../record_yes_no/1.네_66.wav
# (40, 248)
# file name : ../record_yes_no/1.네_50.wav
# (40, 248)
# file name : ../record_yes_no/1.네_23.wav
# (40, 248)
# file name : ../record_yes_no/1.네_17.wav
# (40, 248)

# %%
features_val_df
# Out:
#                                               feature  class_label
# 0   [[-595.2994, -595.2994, -554.8077, -510.07285,...            1
# 1   [[-535.91754, -478.7854, -448.18137, -452.6045...            0
# 2   [[-672.7411, -664.90497, -536.2011, -476.73666...            0
# 3   [[-599.9812, -599.9812, -506.4029, -459.83615,...            1
# 4   [[-651.427, -651.427, -576.0465, -526.0315, -5...            0
# 5   [[-563.5164, -563.5164, -563.5164, -563.5164, ...            1
# 6   [[-595.73615, -595.73615, -570.3427, -458.0125...            1
# 7   [[-559.06305, -559.06305, -559.06305, -559.063...            1
# 8   [[-720.5716, -685.3179, -501.31595, -456.06998...            1
# 9   [[-675.41406, -672.6791, -630.1419, -560.81915...            1
# 10  [[-641.7555, -641.03656, -611.48755, -571.7958...            1
# 11  [[-609.10834, -609.10834, -493.19226, -435.876...            1
# 12  [[-669.1978, -669.1978, -572.9129, -486.8001, ...            1
# 13  [[-668.5468, -656.84436, -542.9314, -491.7875,...            0
# 14  [[-675.1174, -666.04877, -528.0907, -472.25958...            0
# 15  [[-619.91693, -619.91693, -591.39087, -529.276...            1
# 16  [[-603.89886, -412.1689, -186.30266, -164.9628...            1
# 17  [[-672.0635, -664.9937, -490.88165, -429.17972...            0
# 18  [[-634.96893, -631.34753, -544.73926, -505.907...            0
# 19  [[-594.89453, -562.62006, -486.90604, -407.088...            1
# 20  [[-595.63245, -595.63245, -580.86993, -485.396...            1
# 21  [[-640.5128, -527.37225, -486.75107, -485.9001...            0
# 22  [[-609.7063, -467.3424, -441.061, -468.46735, ...            0
# 23  [[-633.996, -632.60895, -604.4427, -565.26996,...            1
# 24  [[-729.2698, -729.2698, -618.3422, -547.0307, ...            1
# 25  [[-644.09863, -644.09863, -632.59015, -527.272...            1
# 26  [[-609.4728, -609.4728, -565.9793, -410.25943,...            1

# %%
np.array(features_df.feature.tolist()).shape
# Out:
# (106, 40, 248)

# %%
X_train = np.array(features_df.feature.tolist())
y_train = np.array(features_df.class_label.tolist())

# %%
X_train.shape
# Out:
# (106, 40, 248)

# %%
X_val = np.array(features_val_df.feature.tolist())
y_val = np.array(features_val_df.class_label.tolist())

# %%
X_val.shape
# Out:
# (27, 40, 248)

# %%
num_rows = n_mfcc
num_columns = max(shapes)
num_channels = 1

X_train = X_train.reshape(X_train.shape[0], num_rows, num_columns, num_channels)
X_val = X_val.reshape(X_val.shape[0], num_rows, num_columns, num_channels)

# %%
X_train.shape
# Out:
# (106, 40, 248, 1)

# %% [markdown]
# # 모델 생성

# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, LSTM
from tensorflow.keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam
from sklearn import metrics

# %% [markdown]
# ## 콜백

# %%
### ReduceLROnPlateau 콜백

reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
    monitor = 'val_accuracy',
    patience = 2,
    verbose = 1,
    factor = 0.5,
    min_lr = 0.000000001
)

# %%
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor = 'val_accuracy',
    patience = 5,
    verbose = 1,
    mode = 'max'
)

# %%
checkpoint = tf.keras.callbacks.ModelCheckpoint(
    monitor = 'val_accuracy',
    filepath = 'mfcc_.{epoch:02d}-{val_accuracy:.6f}.hdf5',
    verbose = 1,
    save_best_only = True,
    save_weights_only = True
)

# %%
#CNN모델 구현
model = Sequential()
model.add(Conv2D(filters=32, kernel_size=3, input_shape=(num_rows, num_columns, num_channels), 
                 padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size = 2))
model.add(Dropout(0.25))

model.add(Conv2D(filters=64, kernel_size=3, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size = 2))
model.add(Dropout(0.25))

model.add(Conv2D(filters=64, kernel_size=3, activation='relu'))
model.add(MaxPooling2D(pool_size = 2))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.25))
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.25))
model.add(Dense(len(wav_dict), activation = 'sigmoid'))

model.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_23 (Conv2D)          (None, 40, 248, 32)       320
#
#  max_pooling2d_23 (MaxPoolin  (None, 20, 124, 32)      0
#  g2D)
#
#  dropout_41 (Dropout)        (None, 20, 124, 32)       0
#
#  conv2d_24 (Conv2D)          (None, 20, 124, 64)       18496
#
#  max_pooling2d_24 (MaxPoolin  (None, 10, 62, 64)       0
#  g2D)
#
#  dropout_42 (Dropout)        (None, 10, 62, 64)        0
#
#  conv2d_25 (Conv2D)          (None, 8, 60, 64)         36928
#
#  max_pooling2d_25 (MaxPoolin  (None, 4, 30, 64)        0
#  g2D)
#
#  dropout_43 (Dropout)        (None, 4, 30, 64)         0
#
#  flatten_9 (Flatten)         (None, 7680)              0
#
#  dense_27 (Dense)            (None, 512)               3932672
#
#  dropout_44 (Dropout)        (None, 512)               0
#
#  dense_28 (Dense)            (None, 256)               131328
#
#  dropout_45 (Dropout)        (None, 256)               0
#
#  dense_29 (Dense)            (None, 2)                 514
#
# =================================================================
# Total params: 4,120,258
# Trainable params: 4,120,258
# Non-trainable params: 0
# _________________________________________________________________

# %%
#CNN모델 구현
model = Sequential()
model.add(Conv2D(filters=32, kernel_size=3, input_shape=(num_rows, num_columns, num_channels), 
                 padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size = 2))
model.add(Dropout(0.25))

model.add(Conv2D(filters=64, kernel_size=3, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size = 2))
model.add(Dropout(0.25))

model.add(Conv2D(filters=64, kernel_size=3, activation='relu'))
model.add(MaxPooling2D(pool_size = 2))
model.add(Dropout(0.25))

model.add(Flatten(256))
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.25))
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.25))
model.add(Dense(len(wav_dict), activation = 'softmax'))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[295], line 17
#      14 model.add(Dropout(0.25))
#      16 # model.add(Flatten(256))
# ---> 17 model.add(LSTM(64))
#      18 model.add(Dense(512, activation='relu'))
#      19 model.add(Dropout(0.25))
#
# File ~/venv/dlproject/lib/python3.8/site-packages/tensorflow/python/trackable/base.py:205, in no_automatic_dependency_tracking.<locals>._method_wrapper(self, *args, **kwargs)
#     203 self._self_setattr_tracking = False  # pylint: disable=protected-access
#     204 try:
# --> 205   result = method(self, *args, **kwargs)
#     206 finally:
#     207   self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# File ~/venv/dlproject/lib/python3.8/site-packages/keras/utils/traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~/venv/dlproject/lib/python3.8/site-packages/keras/engine/input_spec.py:232, in assert_input_compatibility(input_spec, inputs, layer_name)
#     230     ndim = shape.rank
#     231     if ndim != spec.ndim:
# --> 232         raise ValueError(
#     233             f'Input {input_index} of layer "{layer_name}" '
#     234             "is incompatible with the layer: "
#     235             f"expected ndim={spec.ndim}, found ndim={ndim}. "
#     236             f"Full shape received: {tuple(shape)}"
#     237         )
#     238 if spec.max_ndim is not None:
#     239     ndim = x.shape.rank
#
# ValueError: Input 0 of layer "lstm" is incompatible with the layer: expected ndim=3, found ndim=4. Full shape received: (None, 4, 30, 64)

# %%
model.compile(loss = 'sparse_categorical_crossentropy',
              optimizer = 'adam',
              metrics = 'accuracy')

# %% [markdown]
# ## 모델 훈련

# %%
history = model.fit(X_train,
                 y_train,
                 epochs=100,
                 verbose=1,
                 validation_data=(X_val, y_val)
                )#callbacks = [reduce_lr, early_stopping, checkpoint])
# Out:
# Epoch 1/100
# 2023-01-19 15:52:18.626834: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape insequential_9/dropout_41/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 4/4 [==============================] - 2s 60ms/step - loss: 42.2394 - accuracy: 0.5377 - val_loss: 1.2138 - val_accuracy: 0.3704
# Epoch 2/100
# 4/4 [==============================] - 0s 20ms/step - loss: 4.6946 - accuracy: 0.4434 - val_loss: 0.6807 - val_accuracy: 0.6667
# Epoch 3/100
# 4/4 [==============================] - 0s 38ms/step - loss: 1.3937 - accuracy: 0.6792 - val_loss: 0.6707 - val_accuracy: 0.5926
# Epoch 4/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.7497 - accuracy: 0.6132 - val_loss: 0.6793 - val_accuracy: 0.5556
# Epoch 5/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.6502 - accuracy: 0.6226 - val_loss: 0.6872 - val_accuracy: 0.5926
# Epoch 6/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.5930 - accuracy: 0.6226 - val_loss: 0.6771 - val_accuracy: 0.6296
# Epoch 7/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.6200 - accuracy: 0.6604 - val_loss: 0.6659 - val_accuracy: 0.6667
# Epoch 8/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.5992 - accuracy: 0.6321 - val_loss: 0.6679 - val_accuracy: 0.6667
# Epoch 9/100
# 4/4 [==============================] - 0s 23ms/step - loss: 0.6044 - accuracy: 0.6887 - val_loss: 0.6733 - val_accuracy: 0.6667
# Epoch 10/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.5929 - accuracy: 0.6415 - val_loss: 0.6865 - val_accuracy: 0.6667
# Epoch 11/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.5547 - accuracy: 0.7453 - val_loss: 0.6981 - val_accuracy: 0.6667
# Epoch 12/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.5658 - accuracy: 0.6887 - val_loss: 0.7138 - val_accuracy: 0.6296
# Epoch 13/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.5600 - accuracy: 0.6604 - val_loss: 0.7369 - val_accuracy: 0.6296
# Epoch 14/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.6136 - accuracy: 0.6698 - val_loss: 0.7392 - val_accuracy: 0.6296
# Epoch 15/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.5673 - accuracy: 0.7453 - val_loss: 0.7327 - val_accuracy: 0.6296
# Epoch 16/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.5774 - accuracy: 0.6509 - val_loss: 0.7149 - val_accuracy: 0.6296
# Epoch 17/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.5758 - accuracy: 0.6887 - val_loss: 0.7065 - val_accuracy: 0.6296
# Epoch 18/100
# 4/4 [==============================] - 0s 20ms/step - loss: 0.5681 - accuracy: 0.6887 - val_loss: 0.7019 - val_accuracy: 0.6296
# Epoch 19/100
# 4/4 [==============================] - 0s 19ms/step - loss: 0.5799 - accuracy: 0.6604 - val_loss: 0.6866 - val_accuracy: 0.6296
# Epoch 20/100
# 4/4 [==============================] - 0s 19ms/step - loss: 0.5517 - accuracy: 0.7075 - val_loss: 0.6824 - val_accuracy: 0.6667
# Epoch 21/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.5573 - accuracy: 0.6509 - val_loss: 0.6856 - val_accuracy: 0.6296
# Epoch 22/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.5440 - accuracy: 0.7358 - val_loss: 0.6975 - val_accuracy: 0.6296
# Epoch 23/100
# 4/4 [==============================] - 0s 19ms/step - loss: 0.5711 - accuracy: 0.6604 - val_loss: 0.6984 - val_accuracy: 0.6667
# Epoch 24/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.5732 - accuracy: 0.6792 - val_loss: 0.6806 - val_accuracy: 0.6667
# Epoch 25/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.5616 - accuracy: 0.7264 - val_loss: 0.6631 - val_accuracy: 0.6667
# Epoch 26/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.5502 - accuracy: 0.7170 - val_loss: 0.6655 - val_accuracy: 0.6667
# Epoch 27/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.5437 - accuracy: 0.7547 - val_loss: 0.6794 - val_accuracy: 0.7407
# Epoch 28/100
# 4/4 [==============================] - 0s 19ms/step - loss: 0.5310 - accuracy: 0.7358 - val_loss: 0.6959 - val_accuracy: 0.7407
# Epoch 29/100
# 4/4 [==============================] - 0s 20ms/step - loss: 0.5449 - accuracy: 0.7358 - val_loss: 0.6961 - val_accuracy: 0.7037
# Epoch 30/100
# 4/4 [==============================] - 0s 19ms/step - loss: 0.5731 - accuracy: 0.7264 - val_loss: 0.6988 - val_accuracy: 0.7407
# Epoch 31/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.4766 - accuracy: 0.7736 - val_loss: 0.7090 - val_accuracy: 0.7407
# Epoch 32/100
# 4/4 [==============================] - 0s 19ms/step - loss: 0.5794 - accuracy: 0.6981 - val_loss: 0.6890 - val_accuracy: 0.7037
# Epoch 33/100
# 4/4 [==============================] - 0s 20ms/step - loss: 0.5215 - accuracy: 0.6981 - val_loss: 0.6729 - val_accuracy: 0.7037
# Epoch 34/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.5105 - accuracy: 0.7170 - val_loss: 0.6936 - val_accuracy: 0.7407
# Epoch 35/100
# 4/4 [==============================] - 0s 20ms/step - loss: 0.5183 - accuracy: 0.6887 - val_loss: 0.6558 - val_accuracy: 0.6667
# Epoch 36/100
# 4/4 [==============================] - 0s 19ms/step - loss: 0.5783 - accuracy: 0.6887 - val_loss: 0.6431 - val_accuracy: 0.6667
# Epoch 37/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.5348 - accuracy: 0.6887 - val_loss: 0.7260 - val_accuracy: 0.6667
# Epoch 38/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.5431 - accuracy: 0.7358 - val_loss: 0.6919 - val_accuracy: 0.7037
# Epoch 39/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.5193 - accuracy: 0.7264 - val_loss: 0.7431 - val_accuracy: 0.7037
# Epoch 40/100
# 4/4 [==============================] - 0s 19ms/step - loss: 0.5051 - accuracy: 0.7358 - val_loss: 0.8108 - val_accuracy: 0.7037
# Epoch 41/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.5185 - accuracy: 0.6887 - val_loss: 0.6805 - val_accuracy: 0.7778
# Epoch 42/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.4861 - accuracy: 0.7547 - val_loss: 0.6712 - val_accuracy: 0.7778
# Epoch 43/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.4660 - accuracy: 0.7453 - val_loss: 0.8179 - val_accuracy: 0.6667
# Epoch 44/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.4680 - accuracy: 0.7358 - val_loss: 0.5914 - val_accuracy: 0.6667
# Epoch 45/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.4412 - accuracy: 0.7736 - val_loss: 0.7263 - val_accuracy: 0.8148
# Epoch 46/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.4419 - accuracy: 0.7642 - val_loss: 0.6189 - val_accuracy: 0.6667
# Epoch 47/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.4409 - accuracy: 0.7736 - val_loss: 0.8496 - val_accuracy: 0.7037
# Epoch 48/100
# 4/4 [==============================] - 0s 19ms/step - loss: 0.3927 - accuracy: 0.8208 - val_loss: 0.7451 - val_accuracy: 0.8148
# Epoch 49/100
# 4/4 [==============================] - 0s 19ms/step - loss: 0.3901 - accuracy: 0.7830 - val_loss: 0.6171 - val_accuracy: 0.8148
# Epoch 50/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.3198 - accuracy: 0.8585 - val_loss: 0.8763 - val_accuracy: 0.6667
# Epoch 51/100
# 4/4 [==============================] - 0s 20ms/step - loss: 0.3486 - accuracy: 0.8396 - val_loss: 0.5760 - val_accuracy: 0.7037
# Epoch 52/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.3989 - accuracy: 0.8113 - val_loss: 0.8455 - val_accuracy: 0.7778
# Epoch 53/100
# 4/4 [==============================] - 0s 19ms/step - loss: 0.2742 - accuracy: 0.9245 - val_loss: 0.6964 - val_accuracy: 0.7407
# Epoch 54/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.3300 - accuracy: 0.8302 - val_loss: 0.6168 - val_accuracy: 0.8148
# Epoch 55/100
# 4/4 [==============================] - 0s 19ms/step - loss: 0.2930 - accuracy: 0.8585 - val_loss: 0.6088 - val_accuracy: 0.8519
# Epoch 56/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.2983 - accuracy: 0.8302 - val_loss: 0.8865 - val_accuracy: 0.7037
# Epoch 57/100
# 4/4 [==============================] - 0s 19ms/step - loss: 0.2766 - accuracy: 0.8585 - val_loss: 0.5878 - val_accuracy: 0.8148
# Epoch 58/100
# 4/4 [==============================] - 0s 19ms/step - loss: 0.2005 - accuracy: 0.9340 - val_loss: 0.6384 - val_accuracy: 0.8148
# Epoch 59/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.2127 - accuracy: 0.8962 - val_loss: 0.7234 - val_accuracy: 0.7778
# Epoch 60/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.3011 - accuracy: 0.8868 - val_loss: 1.0189 - val_accuracy: 0.8148
# Epoch 61/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.2214 - accuracy: 0.9151 - val_loss: 0.7091 - val_accuracy: 0.7037
# Epoch 62/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.2377 - accuracy: 0.9151 - val_loss: 0.8169 - val_accuracy: 0.8148
# Epoch 63/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.2075 - accuracy: 0.9151 - val_loss: 0.6831 - val_accuracy: 0.6296
# Epoch 64/100
# 4/4 [==============================] - 0s 19ms/step - loss: 0.2936 - accuracy: 0.8774 - val_loss: 1.5399 - val_accuracy: 0.7407
# Epoch 65/100
# 4/4 [==============================] - 0s 19ms/step - loss: 0.2980 - accuracy: 0.8962 - val_loss: 0.6564 - val_accuracy: 0.6296
# Epoch 66/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.2308 - accuracy: 0.9151 - val_loss: 1.3658 - val_accuracy: 0.7407
# Epoch 67/100
# 4/4 [==============================] - 0s 20ms/step - loss: 0.2074 - accuracy: 0.9057 - val_loss: 1.1781 - val_accuracy: 0.8148
# Epoch 68/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.1513 - accuracy: 0.9528 - val_loss: 1.2647 - val_accuracy: 0.7407
# Epoch 69/100
# 4/4 [==============================] - 0s 20ms/step - loss: 0.1221 - accuracy: 0.9528 - val_loss: 1.6432 - val_accuracy: 0.7778
# Epoch 70/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0649 - accuracy: 0.9811 - val_loss: 1.3817 - val_accuracy: 0.7778
# Epoch 71/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0878 - accuracy: 0.9528 - val_loss: 1.3392 - val_accuracy: 0.7778
# Epoch 72/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0524 - accuracy: 0.9906 - val_loss: 1.1763 - val_accuracy: 0.7778
# Epoch 73/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0825 - accuracy: 0.9623 - val_loss: 0.9744 - val_accuracy: 0.7407
# Epoch 74/100
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0713 - accuracy: 0.9717 - val_loss: 0.9920 - val_accuracy: 0.7037
# Epoch 75/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0904 - accuracy: 0.9717 - val_loss: 1.0948 - val_accuracy: 0.7407
# Epoch 76/100
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0694 - accuracy: 0.9811 - val_loss: 1.2057 - val_accuracy: 0.7778
# Epoch 77/100
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0761 - accuracy: 0.9717 - val_loss: 1.2527 - val_accuracy: 0.7778
# Epoch 78/100
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0964 - accuracy: 0.9528 - val_loss: 1.2663 - val_accuracy: 0.7778
# Epoch 79/100
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0115 - accuracy: 1.0000 - val_loss: 1.2467 - val_accuracy: 0.7037
# Epoch 80/100
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0827 - accuracy: 0.9623 - val_loss: 1.5909 - val_accuracy: 0.7778
# Epoch 81/100
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0097 - accuracy: 1.0000 - val_loss: 1.5954 - val_accuracy: 0.8148
# Epoch 82/100
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0415 - accuracy: 0.9717 - val_loss: 1.3392 - val_accuracy: 0.7407
# Epoch 83/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0846 - accuracy: 0.9717 - val_loss: 1.3055 - val_accuracy: 0.7407
# Epoch 84/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.1511 - accuracy: 0.9434 - val_loss: 1.3619 - val_accuracy: 0.7407
# Epoch 85/100
# 4/4 [==============================] - 0s 19ms/step - loss: 0.1552 - accuracy: 0.9057 - val_loss: 1.1429 - val_accuracy: 0.7778
# Epoch 86/100
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0311 - accuracy: 1.0000 - val_loss: 2.0989 - val_accuracy: 0.8148
# Epoch 87/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.1912 - accuracy: 0.9057 - val_loss: 1.0505 - val_accuracy: 0.7407
# Epoch 88/100
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0526 - accuracy: 0.9811 - val_loss: 1.1522 - val_accuracy: 0.7407
# Epoch 89/100
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0395 - accuracy: 0.9811 - val_loss: 1.3835 - val_accuracy: 0.7037
# Epoch 90/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0082 - accuracy: 1.0000 - val_loss: 1.6744 - val_accuracy: 0.6296
# Epoch 91/100
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0281 - accuracy: 0.9906 - val_loss: 2.2770 - val_accuracy: 0.7407
# Epoch 92/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0332 - accuracy: 0.9811 - val_loss: 2.0438 - val_accuracy: 0.6667
# Epoch 93/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0244 - accuracy: 0.9906 - val_loss: 2.2142 - val_accuracy: 0.7037
# Epoch 94/100
# 4/4 [==============================] - 0s 20ms/step - loss: 0.1903 - accuracy: 0.9623 - val_loss: 2.9280 - val_accuracy: 0.7778
# Epoch 95/100
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0885 - accuracy: 0.9717 - val_loss: 2.3225 - val_accuracy: 0.7407
# Epoch 96/100
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0311 - accuracy: 0.9811 - val_loss: 1.6166 - val_accuracy: 0.7037
# Epoch 97/100
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0246 - accuracy: 0.9906 - val_loss: 1.5200 - val_accuracy: 0.7037
# Epoch 98/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0487 - accuracy: 0.9906 - val_loss: 1.5676 - val_accuracy: 0.6667
# Epoch 99/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0404 - accuracy: 0.9811 - val_loss: 2.1386 - val_accuracy: 0.7037
# Epoch 100/100
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0533 - accuracy: 0.9811 - val_loss: 2.3929 - val_accuracy: 0.7037

# %%
import seaborn as sns

fig, axes = plt.subplots(1, 2, figsize = (12, 4))

sns.lineplot(x = range(len(history.history['loss'])),
             y = history.history['loss'], ax = axes[0],
             label = 'Training Loss')

sns.lineplot(x = range(len(history.history['loss'])),
             y = history.history['val_loss'], ax = axes[0],
             label = 'Validation Loss')

sns.lineplot(x = range(len(history.history['accuracy'])),
             y = history.history['accuracy'], ax = axes[1],
             label = 'Training Accuracy')

sns.lineplot(x = range(len(history.history['accuracy'])),
             y = history.history['val_accuracy'], ax = axes[1],
             label = 'Validation Accuracy')
axes[0].set_title('Loss')
axes[1].set_title('Accuracy')

sns.despine()
plt.show()

# %%
def predict_features(file_name, max_pad_len, n_mfcc):
    audio, sample_rate = librosa.load(file_name, res_type='kaiser_fast') 
    mfccs = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=n_mfcc)
    pad_width = max_pad_len - mfccs.shape[1]
    mfccs = np.pad(mfccs, pad_width=((0, 0), (0, pad_width)), mode='constant')
    mfccs = mfccs.reshape(1, n_mfcc, max_pad_len, 1)
    
    return mfccs

# %%
val_data
# Out:
#                                  path label  class_label
# 64        ../record_yes_no/1.네_88.wav     네            1
# 32   ../record_yes_no/1.아니요_준석형_1.wav   아니요            0
# 111     ../record_yes_no/1.아니요_25.wav   아니요            0
# 120        ../record_yes_no/1.네_3.wav     네            1
# 41      ../record_yes_no/1.아니요_21.wav   아니요            0
# 76        ../record_yes_no/1.네_96.wav     네            1
# 59        ../record_yes_no/1.네_15.wav     네            1
# 42        ../record_yes_no/1.네_54.wav     네            1
# 74        ../record_yes_no/1.네_25.wav     네            1
# 91        ../record_yes_no/1.네_65.wav     네            1
# 139       ../record_yes_no/1.네_80.wav     네            1
# 33         ../record_yes_no/1.네_7.wav     네            1
# 25        ../record_yes_no/1.네_22.wav     네            1
# 94      ../record_yes_no/1.아니요_41.wav   아니요            0
# 35      ../record_yes_no/1.아니요_27.wav   아니요            0
# 44        ../record_yes_no/1.네_60.wav     네            1
# 108        ../record_yes_no/1.네_5.wav     네            1
# 102     ../record_yes_no/1.아니요_38.wav   아니요            0
# 112     ../record_yes_no/1.아니요_15.wav   아니요            0
# 128       ../record_yes_no/1.네_68.wav     네            1
# 58        ../record_yes_no/1.네_93.wav     네            1
# 65   ../record_yes_no/1.아니요_경환님_2.wav   아니요            0
# 142  ../record_yes_no/1.아니요_경환님_3.wav   아니요            0
# 53        ../record_yes_no/1.네_66.wav     네            1
# 38        ../record_yes_no/1.네_50.wav     네            1
# 123       ../record_yes_no/1.네_23.wav     네            1
# 78        ../record_yes_no/1.네_17.wav     네            1

# %%
test_data
# Out:
#                                  path label  class_label
# 4       ../record_yes_no/1.아니요_16.wav   아니요            0
# 137     ../record_yes_no/1.아니요_28.wav   아니요            0
# 16      ../record_yes_no/1.아니요_30.wav   아니요            0
# 14        ../record_yes_no/1.네_59.wav     네            1
# 70   ../record_yes_no/1.아니요_동준님_3.wav   아니요            0
# 48        ../record_yes_no/1.네_75.wav     네            1
# 140       ../record_yes_no/1.네_51.wav     네            1
# 11        ../record_yes_no/1.네_11.wav     네            1
# 107       ../record_yes_no/1.네_29.wav     네            1
# 34        ../record_yes_no/1.네_45.wav     네            1
# 145       ../record_yes_no/1.네_67.wav     네            1
# 95        ../record_yes_no/1.네_82.wav     네            1
# 85      ../record_yes_no/1.아니요_39.wav   아니요            0
# 29         ../record_yes_no/1.네_9.wav     네            1
# 87        ../record_yes_no/1.네_83.wav     네            1

# %%
np.argmax(model.predict(predict_features('../record/아_2.wav', max(shapes), n_mfcc)))
# Out:
# 1/1 [==============================] - 0s 121ms/step
# 1

# %%
# Count wrong data
cnt = 0

for i, data in enumerate(val_data['path']):
    prediction = np.argmax(model.predict(predict_features(data, max(shapes), n_mfcc)))
    real = val_data.iloc[i, 2]
    print('predict :', prediction)
    print('real :', real)
    if prediction != real:
        cnt += 1

print('count :', cnt, '/', len(val_data))
# Out:
# 1/1 [==============================] - 0s 114ms/step
# predict : 1
# real : 1
# 1/1 [==============================] - 0s 28ms/step
# predict : 1
# real : 0
# 1/1 [==============================] - 0s 19ms/step
# predict : 0
# real : 0
# 1/1 [==============================] - 0s 19ms/step
# predict : 1
# real : 1
# 1/1 [==============================] - 0s 27ms/step
# predict : 0
# real : 0
# 1/1 [==============================] - 0s 26ms/step
# predict : 1
# real : 1
# 1/1 [==============================] - 0s 31ms/step
# predict : 0
# real : 1
# 1/1 [==============================] - 0s 28ms/step
# predict : 1
# real : 1
# 1/1 [==============================] - 0s 23ms/step
# predict : 1
# real : 1
# 1/1 [==============================] - 0s 31ms/step
# predict : 1
# real : 1
# 1/1 [==============================] - 0s 23ms/step
# predict : 1
# real : 1
# 1/1 [==============================] - 0s 22ms/step
# predict : 1
# real : 1
# 1/1 [==============================] - 0s 28ms/step
# predict : 1
# real : 1
# 1/1 [==============================] - 0s 19ms/step
# predict : 1
# real : 0
# 1/1 [==============================] - 0s 27ms/step
# predict : 1
# real : 0
# 1/1 [==============================] - 0s 23ms/step
# predict : 1
# real : 1
# 1/1 [==============================] - 0s 22ms/step
# predict : 1
# real : 1
# 1/1 [==============================] - 0s 25ms/step
# predict : 1
# real : 0
# 1/1 [==============================] - 0s 19ms/step
# predict : 1
# real : 0
# 1/1 [==============================] - 0s 43ms/step
# predict : 1
# real : 1
# 1/1 [==============================] - 0s 37ms/step
# predict : 1
# real : 1
# 1/1 [==============================] - 0s 27ms/step
# predict : 1
# real : 0
# 1/1 [==============================] - 0s 27ms/step
# predict : 1
# real : 0
# 1/1 [==============================] - 0s 29ms/step
# predict : 1
# real : 1
# 1/1 [==============================] - 0s 30ms/step
# predict : 1
# real : 1
# 1/1 [==============================] - 0s 27ms/step
# predict : 1
# real : 1
# 1/1 [==============================] - 0s 24ms/step
# predict : 1
# real : 1
# count : 8 / 27

# %%
# Count wrong data
cnt = 0

for i, data in enumerate(test_data['path']):
    prediction = np.argmax(model.predict(predict_features(data, max(shapes), n_mfcc)))
    real = test_data.iloc[i, 2]
    print('predict :', prediction)
    print('real :', real)
    if prediction != real:
        cnt += 1

print('count :', cnt, '/', len(test_data))
# Out:
# 1/1 [==============================] - 0s 23ms/step
# predict : 0
# real : 0
# 1/1 [==============================] - 0s 18ms/step
# predict : 1
# real : 0
# 1/1 [==============================] - 0s 19ms/step
# predict : 1
# real : 0
# 1/1 [==============================] - 0s 20ms/step
# predict : 1
# real : 1
# 1/1 [==============================] - 0s 36ms/step
# predict : 0
# real : 0
# 1/1 [==============================] - 0s 38ms/step
# predict : 1
# real : 1
# 1/1 [==============================] - 0s 28ms/step
# predict : 1
# real : 1
# 1/1 [==============================] - 0s 32ms/step
# predict : 1
# real : 1
# 1/1 [==============================] - 0s 32ms/step
# predict : 1
# real : 1
# 1/1 [==============================] - 0s 35ms/step
# predict : 1
# real : 1
# 1/1 [==============================] - 0s 27ms/step
# predict : 1
# real : 1
# 1/1 [==============================] - 0s 32ms/step
# predict : 1
# real : 1
# 1/1 [==============================] - 0s 30ms/step
# predict : 1
# real : 0
# 1/1 [==============================] - 0s 32ms/step
# predict : 1
# real : 1
# 1/1 [==============================] - 0s 28ms/step
# predict : 1
# real : 1
# count : 3 / 15

# %%
train_data.iloc[0:10, 0]
# Out:
# 30          ../record_yes_no/1.네_1.wav
# 79       ../record_yes_no/1.아니요_13.wav
# 24    ../record_yes_no/1.아니요_준석형_1.wav
# 78       ../record_yes_no/1.아니요_36.wav
# 68       ../record_yes_no/1.아니요_23.wav
# 28         ../record_yes_no/1.네_19.wav
# 3        ../record_yes_no/1.아니요_32.wav
# 46         ../record_yes_no/1.네_14.wav
# 42       ../record_yes_no/1.아니요_29.wav
# 44          ../record_yes_no/1.네_2.wav
# Name: path, dtype: object

# %%
cnt = 0

for i, data in enumerate(train_data.iloc[0:10, 0]):
    prediction = np.argmax(model.predict(predict_features(data, max(shapes), n_mfcc)))
    real = train_data.iloc[i, 2]
    print('predict :', prediction)
    print('real :', real)
    if prediction != real:
        cnt += 1

print('count :', cnt, '/', len(train_data.iloc[2:10, 0]))
# Out:
# 1/1 [==============================] - 0s 28ms/step
# predict : 1
# real : 1
# 1/1 [==============================] - 0s 23ms/step
# predict : 0
# real : 0
# 1/1 [==============================] - 0s 25ms/step
# predict : 0
# real : 0
# 1/1 [==============================] - 0s 21ms/step
# predict : 0
# real : 0
# 1/1 [==============================] - 0s 19ms/step
# predict : 0
# real : 0
# 1/1 [==============================] - 0s 29ms/step
# predict : 1
# real : 1
# 1/1 [==============================] - 0s 23ms/step
# predict : 0
# real : 0
# 1/1 [==============================] - 0s 48ms/step
# predict : 1
# real : 1
# 1/1 [==============================] - 0s 23ms/step
# predict : 0
# real : 0
# 1/1 [==============================] - 0s 41ms/step
# predict : 1
# real : 1
# count : 0 / 8

# %% [markdown]
# # 음성 인식

# %%
reverse_dict= dict(map(reversed, wav_dict.items()))

# %%
reverse_dict
# Out:
# {0: '아니요', 1: '네'}

# %%
import librosa
import sounddevice as sd
import numpy as np

# Collect microphone audio for 5 seconds
fs = 22050  # Sample rate
duration = 5  # Seconds
recording = sd.rec(int(fs * duration), samplerate=fs, channels=1)
sd.wait()
print('recording...')
recording = recording.flatten()
print(recording.shape)
# Extract MFCCs from microphone recording
mfccs = librosa.feature.mfcc(y=recording, sr=librosa_sample_rate, n_mfcc=n_mfcc)
pad_width = max_pad_len - mfccs.shape[1]
print('pad_width', pad_width)
mfccs = np.pad(mfccs, pad_width=((0, 0), (0, pad_width)), mode='constant')
mfccs = mfccs.reshape(1, n_mfcc, max_pad_len, 1)
print(mfccs)
print(librosa_sample_rate)
print(mfccs.shape)

# # Use MFCCs as input to your CNN model
prediction = model.predict(mfccs)
print(prediction)
print(reverse_dict[np.argmax(prediction[0])])
# Out:
# recording...
# (110250,)
# pad_width 32
# [[[[-390.1099   ]
#    [-361.9483   ]
#    [-336.6068   ]
#    ...
#    [   0.       ]
#    [   0.       ]
#    [   0.       ]]
#
#   [[ 108.83345  ]
#    [  98.00206  ]
#    [  75.67023  ]
#    ...
#    [   0.       ]
#    [   0.       ]
#    [   0.       ]]
#
#   [[  -9.996052 ]
#    [ -15.610128 ]
#    [ -10.258675 ]
#    ...
#    [   0.       ]
#    [   0.       ]
#    [   0.       ]]
#
#   ...
#
#   [[   5.2111506]
#    [   1.181324 ]
#    [   2.0237212]
#    ...
#    [   0.       ]
#    [   0.       ]
#    [   0.       ]]
#
#   [[   3.1802545]
#    [   2.2358198]
#    [   5.903119 ]
#    ...
#    [   0.       ]
#    [   0.       ]
#    [   0.       ]]
#
#   [[  -2.0388956]
#    [   1.0375209]
#    [   4.963407 ]
#    ...
#    [   0.       ]
#    [   0.       ]
#    [   0.       ]]]]
# 22050
# (1, 40, 248, 1)
# 1/1 [==============================] - 0s 50ms/step
# [[0.00878785 0.8826948 ]]
# 네

# %% [markdown]
# ## pyaudio

# %%
import pyaudio
import wave

CHUNK = 1024
FORMAT = pyaudio.paInt16
CHANNELS = 2
RATE = 22050

p = pyaudio.PyAudio()

stream = p.open(format=FORMAT,
                channels=CHANNELS,
                rate=RATE,
                input=True,
                frames_per_buffer=CHUNK)

print("start recording...")

frames = []
seconds = 5

for i in range(0, int(RATE / CHUNK*seconds)):
    data = stream.read(CHUNK)
    frames.append(data)

print('recording stopped')

stream.stop_stream()
stream.close()
p.terminate()

wf = wave.open("./output.wav", "wb")
wf.setnchannels(CHANNELS)
wf.setsampwidth(p.get_sample_size(FORMAT))
wf.setframerate(RATE)
wf.writeframes(b''.join(frames))
wf.close()

mic_audio, mic_sample_rate = librosa.load("./output.wav")
mfccs = librosa.feature.mfcc(y = mic_audio, sr = librosa_sample_rate, n_mfcc = n_mfcc)
pad_width = max_pad_len - mfccs.shape[1]
print('pad_width', pad_width)
mfccs = np.pad(mfccs, pad_width=((0, 0), (0, pad_width)), mode='constant')
mfccs = mfccs.reshape(1, n_mfcc, max_pad_len, 1)
print(mfccs)
print(librosa_sample_rate)
print(mfccs.shape)

# # Use MFCCs as input to your CNN model
prediction = model.predict(mfccs)
print(prediction)
print(reverse_dict[np.argmax(prediction)])
# Out:
# start recording...
# recording stopped
# pad_width 33
# [[[[-4.3702521e+02]
#    [-2.7943307e+02]
#    [-2.3036838e+02]
#    ...
#    [ 0.0000000e+00]
#    [ 0.0000000e+00]
#    [ 0.0000000e+00]]
#
#   [[ 1.3505682e+02]
#    [ 1.0024167e+02]
#    [ 8.9269569e+01]
#    ...
#    [ 0.0000000e+00]
#    [ 0.0000000e+00]
#    [ 0.0000000e+00]]
#
#   [[ 6.9975319e+00]
#    [-3.3507378e+01]
#    [-4.1581253e+01]
#    ...
#    [ 0.0000000e+00]
#    [ 0.0000000e+00]
#    [ 0.0000000e+00]]
#
#   ...
#
#   [[ 3.7099638e+00]
#    [ 6.9922438e+00]
#    [ 7.8012462e+00]
#    ...
#    [ 0.0000000e+00]
#    [ 0.0000000e+00]
#    [ 0.0000000e+00]]
#
#   [[ 1.5722663e+00]
#    [ 3.3734596e-01]
#    [ 1.0941780e+00]
#    ...
#    [ 0.0000000e+00]
#    [ 0.0000000e+00]
#    [ 0.0000000e+00]]
#
#   [[ 4.7217779e+00]
#    [ 3.1702447e-01]
#    [-1.6781926e-02]
#    ...
#    [ 0.0000000e+00]
#    [ 0.0000000e+00]
#    [ 0.0000000e+00]]]]
# 22050
# (1, 40, 248, 1)
# 1/1 [==============================] - 0s 25ms/step
# [[1.4662576e-05 9.9998534e-01]]
# 네

# %%
draw_sound("./output.wav")

# %%
mic_audio, mic_sample_rate = librosa.load("./output.wav")
print(mic_audio.shape)
print(mic_sample_rate)
mic_audio
# Out:
# (109568,)
# 22050
# array([ 0.        ,  0.        ,  0.        , ..., -0.00354004,
#        -0.00305176, -0.00263977], dtype=float32)

# %%
mic_audio, mic_sample_rate = librosa.load("../record_yes_no/1.네_11.wav")
print(mic_audio.shape)
print(mic_sample_rate)
mic_audio
# Out:
# (108864,)
# 22050
# array([0.        , 0.        , 0.        , ..., 0.02355935, 0.02088976,
#        0.01770592], dtype=float32)

# %% [markdown]
# ## test

# %% [markdown]
# for_test = np.array(10)
